# %% [markdown]
# # AI Engine Raw Tester\n
# Use this notebook to test the pipeline with hardcoded paths before deployment.

# %%
# 1. Setup Environment\n
import os
from main import create_report
from dotenv import load_dotenv
load_dotenv() # Load from .env file
# Out:
# True

# %%
# 2. Hardcoded Test Configuration\n
VIDEO_PATH = '/Users/williamgreners/Documents/GitHub/janitorAI/ai-engine/test_video/Muted Vannlekasjebefaring - Test 2.mov'
CREDS_PATH = 'credentials.json'
MASTER_ID = '1JorwncOF1d8adt5DLxZC8TcL86F8ZFJA16F1u1P9VzY'
FOLDER_ID = '1wGChZHA0-wmDyzzCGJ6B44Rlnd8_zEMM'
GEMINI_KEY = os.getenv('GEMINI_API_KEY') # Or hardcode string here for raw test

# %%
# 3. Run Pipeline\n
report_url = create_report(
    video_path=VIDEO_PATH,
    credentials_path=CREDS_PATH,
    master_id=MASTER_ID,
    output_folder=FOLDER_ID,
    gemini_key=GEMINI_KEY
)
print(f'Done! Check your report here: {report_url}')
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=677328921045-mfris8q3i1sdtkbfglltj556bn6gdaq5.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A61368%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocuments&state=dlT6QWfxMHMNUviQdA0WC2feZGVSME&code_challenge=csM_lKsADJXvtCrytXteU8kJZ5jn5Cn0aISAaLzCyCE&code_challenge_method=S256&access_type=offline
# 🤖 Gemini is analyzing video...
# 📚 Opplasting av kunnskapsbase fra: /Users/williamgreners/Documents/GitHub/janitorAI/ai-engine/knowlegde
# 📚 Uploading knowledge: 700115.pdf
# 📚 Uploading knowledge: 700117.pdf
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # 3. Run Pipeline\n
# ----> 2 report_url = create_report(
#       3     video_path=VIDEO_PATH,
# ...
